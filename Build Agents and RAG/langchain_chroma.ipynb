# %%
# !pip install langchain chromadb openai tiktoken pydf langchain_openai langchain-community
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 30.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.1/125.1 kB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 82.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 18.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 94.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 46.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 63.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 4.0 MB/s eta 0:00:00
# ...

# %%
import os
os.environ["OPENAI_API_KEY"] = "YOUR_OPENAI_API_KEY"

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
# Out:
# /tmp/ipykernel_1096/398303453.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.vectorstores import Chroma

# %%
from langchain_core.documents import Document

# %%
#Create LangChain documents for IPL players
doc1 = Document(
    page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history",
    metadata={"team":"RCB"}
)
doc2 = Document(
    page_content="Rohit Sharma is one of the most successful captain in IPL history",
    metadata={"team":"Mumbai Indians"}
)
doc3 = Document(
    page_content="MS Dhoni famous for Captain Cool",
    metadata={"team":"Chennai Super Kings"}
)
doc4 = Document(
    page_content="Jasprit Bumrah is considered one of the best fast bowlers",
    metadata={"team":"Mumbai Indians"}
)

# %%
# vector_store = Chroma(
#     embedding_function=OpenAIEmbeddings(),
#     persist_directory="chroma_db",
#     collection_name="sample"
# )

# %%
# #add documents
# vector_store.add_documents([doc1,doc2,doc3,doc4])

# %% [markdown]
# View embeddings, docs, metadata

# %%
vector_store.get(include=['embeddings','documents','metadatas'])

# %%
#search documents
vector_store.similarity_search(
    query="who among these are a bowler?",
    k=1
)

# %%
#search with similarity score
vector_store.similarity_search_with_score(
    query="who among these are a bowler?",
    k=1
)

# %%
#meta-data filtering
vector_store.similarity_search(
    query="",
    k=1,
    filter={"team":"Mumbai Indians"}
)

# %%
#update documents
updated_doc1 = Document(
    page_content =""
    metadata = {"team":"RCB"}
)
